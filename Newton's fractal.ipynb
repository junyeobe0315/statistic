# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# x_n+1 = x_n - (f(x_n)/ f'(x_n)) : 다음 뉴턴법 적용할 포인트
# f'(x_n) = (f(x_n+0.00001) - f(x_n)) / 0.00001 라고 하자

def dx_n(function, x_n, epsilon):
    return (function(x_n + epsilon) - function(x_n)) / epsilon

def Newton(function, x, epsilon):
    dx = dx_n(function, x, epsilon)
    x = x - (function(x) / dx)
    return x
        
# 이걸 어떻게 복소평면에 적용할 수 있을까?

# test : f(x) = z^4 - 1
f = lambda z: z**4 - 1

# %%
X_ = []
eps = 0.001
for x in X:
    for _ in range(100):
        x = Newton(np.sin, x, eps)
    X_.append(x)
plt.plot(X_,Y)
